# %% [markdown]
# # PS2
#
# ## Decision Trees

# %% [markdown]
# ### Team members
#
# Notes: This homework can be done individually or by a group (either project group or the group you work in class). If this is done by a group, please write the names of students who work together.
#
# Michael Brown
# Alexander Erickson

# %% [markdown]
# ### Setup

# %% [markdown]
# First, let's import a few common modules, ensure MatplotLib plots figures inline and prepare a function to save the figures. We also check that Python 3.5 or later is installed (although Python 2.x may work, it is deprecated so we strongly recommend you use Python 3 instead), as well as Scikit-Learn ≥0.20.

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)


# to make this notebook's output stable across runs
np.random.seed(42)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "decision_trees"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)

os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# ## Part 0
#
# - Read each cell of the examples below, run and check the outputs.

# %% [markdown]
# ### Confusion matrix plot

# %%
# Show confusion matrix
def plot_confusion_matrix(confusion_mat, cln):
    plt.imshow(confusion_mat, interpolation='nearest', cmap=plt.cm.gray)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(cln)
    plt.xticks(tick_marks, tick_marks)
    plt.yticks(tick_marks, tick_marks)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %% [markdown]
# ### Confusion matrix simple example 1

# %%
y_true = [1, 0, 0, 2, 1, 0, 3, 3, 3]
y_pred = [1, 1, 0, 2, 1, 0, 1, 3, 3]
confusion_mat = confusion_matrix(y_true, y_pred)

print(confusion_mat)
plot_confusion_matrix(confusion_mat, 4)
# Out:
# [[2 1 0 0]
#  [0 2 0 0]
#  [0 0 1 0]
#  [0 1 0 2]]

# %%
# Print classification report
target_names = ['Class-0', 'Class-1', 'Class-2', 'Class-3']

result_metrics = classification_report(y_true, y_pred, target_names=target_names)

print(result_metrics)
# Out:
#               precision    recall  f1-score   support
#
#      Class-0       1.00      0.67      0.80         3
#      Class-1       0.50      1.00      0.67         2
#      Class-2       1.00      1.00      1.00         1
#      Class-3       1.00      0.67      0.80         3
#
#     accuracy                           0.78         9
#    macro avg       0.88      0.83      0.82         9
# weighted avg       0.89      0.78      0.79         9

# %% [markdown]
# ### Confusion matrix simple example 2

# %%
y_true2 = [1, 0, 0, 1, 1, 0, 1, 1, 0]
y_pred2 = [1, 1, 0, 1, 1, 0, 1, 1, 1]
confusion_mat2 = confusion_matrix(y_true2, y_pred2)

print(confusion_mat2)
plot_confusion_matrix(confusion_mat2, 2)
# Out:
# [[2 2]
#  [0 5]]

# %%
# Print classification report
target_names2 = ['Class-0', 'Class-1']

result_metrics = classification_report(y_true2, y_pred2, target_names=target_names2)

print(result_metrics)
# Out:
#               precision    recall  f1-score   support
#
#      Class-0       1.00      0.50      0.67         4
#      Class-1       0.71      1.00      0.83         5
#
#     accuracy                           0.78         9
#    macro avg       0.86      0.75      0.75         9
# weighted avg       0.84      0.78      0.76         9

# %% [markdown]
# ## Data Visualization
#
# ### iris dataset before we start training and testing a model

# %%
import matplotlib.pyplot as plt
import pandas as pd

# read data from CSV file to dataframe
iris = pd.read_csv('./data/iris.csv')
print(iris.head())
print(iris.tail())

# scatter matrix plot
pd.plotting.scatter_matrix(iris);

plt.figure()
pd.plotting.parallel_coordinates(iris, 'Name');
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica

# %% [markdown]
# # Decision Trees
#
# ### Load data
#
# - For the following code, we use sklearn.datasets package for loading a dataset instead of reading a data file stored on a local machine.

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

iris = load_iris()

#print(iris)

# %% [markdown]
# ### Split the data to training and testing

# %%
X = iris.data[:, 2:] # petal length and width
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %% [markdown]
# ## Training
# ### Learing using training data
#
# - use Gini index measure
#
# *** Notes: you can also use gain information (entropy) measure by setting criterion="entropy" in the model

# %%
tree_clf = DecisionTreeClassifier(max_depth=2, criterion="gini", random_state=42)
tree_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=2, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %% [markdown]
# ## Testing
# ### Evaluating the model using testing data

# %%
y_pred = tree_clf.predict(X_test)

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Confusion matrix

# %%
# plot a confusion matrix
confusion_mat = confusion_matrix(y_test, y_pred)

print(confusion_mat)

plot_confusion_matrix(confusion_mat, 3)
# Out:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]

# %% [markdown]
# ### Model performance summary

# %%
# Print classification report
target_names = iris.target_names

result_metrics = classification_report(y_test, y_pred, target_names=target_names)

print(result_metrics)
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
# you can access each class's metrics from result_metrics
result_metrics_dict = classification_report(y_test, y_pred, target_names=target_names, output_dict=True)

print(result_metrics_dict['setosa']['precision'])
# Out:
# 1.0

# %% [markdown]
# ### Draw a decision tree

# %%
from graphviz import Source
from sklearn.tree import export_graphviz

export_graphviz(
        tree_clf,
        out_file=os.path.join(IMAGES_PATH, "iris_tree.dot"),
        feature_names=iris.feature_names[2:],
        class_names=iris.target_names,
        rounded=True,
        filled=True
    )

Source.from_file(os.path.join(IMAGES_PATH, "iris_tree.dot"))

# %% [markdown]
# ## k-Cross Validation
#
# - using sklearn corss_val_score() function

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(tree_clf, iris.data, iris.target, cv=3)
# Out:
# array([0.96, 0.92, 0.92])

# %% [markdown]
# ## k-Cross Validation
#
# - using KFold function with freedom

# %%
from sklearn.model_selection import KFold # import k-fold validation

kf = KFold(n_splits=3, random_state=None, shuffle=True) # Define the split - into 2 folds 

kf.get_n_splits(X) # returns the number of splitting iterations in the cross-validator

print(kf)
# Out:
# KFold(n_splits=3, random_state=None, shuffle=True)

# %% [markdown]
# ### Applying k-Cross Validation

# %%
tree_clf = DecisionTreeClassifier(max_depth=2, random_state=42)

for train_index, test_index in kf.split(X):
    #print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    tree_clf.fit(X_train, y_train)
    
    y_pred = tree_clf.predict(X_test)
    
    # Print classification report
    target_names = iris.target_names
    print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        21
#   versicolor       1.00      0.92      0.96        12
#    virginica       0.94      1.00      0.97        17
#
#     accuracy                           0.98        50
#    macro avg       0.98      0.97      0.98        50
# weighted avg       0.98      0.98      0.98        50
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        16
#   versicolor       0.87      1.00      0.93        20
#    virginica       1.00      0.79      0.88        14
#
#     accuracy                           0.94        50
#    macro avg       0.96      0.93      0.94        50
# weighted avg       0.95      0.94      0.94        50
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       0.89      0.94      0.92        18
#    virginica       0.94      0.89      0.92        19
#
#     accuracy                           0.94        50
#    macro avg       0.95      0.95      0.95        50
# weighted avg       0.94      0.94      0.94        50

# %% [markdown]
# # Decision Tree boundary Visualization

# %%
## Example1

# %%
from matplotlib.colors import ListedColormap

def plot_decision_boundary(clf, X, y, axes=[0, 7.5, 0, 3], iris=True, legend=False, plot_training=True):
    x1s = np.linspace(axes[0], axes[1], 100)
    x2s = np.linspace(axes[2], axes[3], 100)
    x1, x2 = np.meshgrid(x1s, x2s)
    X_new = np.c_[x1.ravel(), x2.ravel()]
    y_pred = clf.predict(X_new).reshape(x1.shape)
    custom_cmap = ListedColormap(['#fafab0','#9898ff','#a0faa0'])
    plt.contourf(x1, x2, y_pred, alpha=0.3, cmap=custom_cmap)
    if not iris:
        custom_cmap2 = ListedColormap(['#7d7d58','#4c4c7f','#507d50'])
        plt.contour(x1, x2, y_pred, cmap=custom_cmap2, alpha=0.8)
    if plot_training:
        plt.plot(X[:, 0][y==0], X[:, 1][y==0], "yo", label="Iris setosa")
        plt.plot(X[:, 0][y==1], X[:, 1][y==1], "bs", label="Iris versicolor")
        plt.plot(X[:, 0][y==2], X[:, 1][y==2], "g^", label="Iris virginica")
        plt.axis(axes)
    if iris:
        plt.xlabel("Petal length", fontsize=14)
        plt.ylabel("Petal width", fontsize=14)
    else:
        plt.xlabel(r"$x_1$", fontsize=18)
        plt.ylabel(r"$x_2$", fontsize=18, rotation=0)
    if legend:
        plt.legend(loc="lower right", fontsize=14)

plt.figure(figsize=(8, 4))
plot_decision_boundary(tree_clf, X, y)
plt.plot([2.45, 2.45], [0, 3], "k-", linewidth=2)
plt.plot([2.45, 7.5], [1.75, 1.75], "k--", linewidth=2)
plt.plot([4.95, 4.95], [0, 1.75], "k:", linewidth=2)
plt.plot([4.85, 4.85], [1.75, 3], "k:", linewidth=2)
plt.text(1.40, 1.0, "Depth=0", fontsize=15)
plt.text(3.2, 1.80, "Depth=1", fontsize=13)
plt.text(4.05, 0.5, "(Depth=2)", fontsize=11)

save_fig("decision_tree_decision_boundaries_plot")
plt.show()
# Out:
# Saving figure decision_tree_decision_boundaries_plot

# %% [markdown]
# # Predicting classes and class probabilities

# %%
tree_clf.predict_proba([[5, 1.5]])
# Out:
# array([[0.        , 0.91428571, 0.08571429]])

# %%
tree_clf.predict([[5, 1.5]])
# Out:
# array([1])

# %% [markdown]
# # Sensitivity to training set details

# %%
X[(X[:, 1]==X[:, 1][y==1].max()) & (y==1)] # widest Iris versicolor flower
# Out:
# array([[4.8, 1.8]])

# %%
not_widest_versicolor = (X[:, 1]!=1.8) | (y==2)
X_tweaked = X[not_widest_versicolor]
y_tweaked = y[not_widest_versicolor]

tree_clf_tweaked = DecisionTreeClassifier(max_depth=2, random_state=40)
tree_clf_tweaked.fit(X_tweaked, y_tweaked)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=2, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=40, splitter='best')

# %%
plt.figure(figsize=(8, 4))
plot_decision_boundary(tree_clf_tweaked, X_tweaked, y_tweaked, legend=False)
plt.plot([0, 7.5], [0.8, 0.8], "k-", linewidth=2)
plt.plot([0, 7.5], [1.75, 1.75], "k--", linewidth=2)
plt.text(1.0, 0.9, "Depth=0", fontsize=15)
plt.text(1.0, 1.80, "Depth=1", fontsize=13)

save_fig("decision_tree_instability_plot")
plt.show()
# Out:
# Saving figure decision_tree_instability_plot

# %%
from sklearn.datasets import make_moons
Xm, ym = make_moons(n_samples=100, noise=0.25, random_state=53)

deep_tree_clf1 = DecisionTreeClassifier(random_state=42)
deep_tree_clf2 = DecisionTreeClassifier(min_samples_leaf=4, random_state=42)
deep_tree_clf1.fit(Xm, ym)
deep_tree_clf2.fit(Xm, ym)

fig, axes = plt.subplots(ncols=2, figsize=(10, 4), sharey=True)
plt.sca(axes[0])
plot_decision_boundary(deep_tree_clf1, Xm, ym, axes=[-1.5, 2.4, -1, 1.5], iris=False)
plt.title("No restrictions", fontsize=16)
plt.sca(axes[1])
plot_decision_boundary(deep_tree_clf2, Xm, ym, axes=[-1.5, 2.4, -1, 1.5], iris=False)
plt.title("min_samples_leaf = {}".format(deep_tree_clf2.min_samples_leaf), fontsize=14)
plt.ylabel("")

save_fig("min_samples_leaf_plot")
plt.show()
# Out:
# Saving figure min_samples_leaf_plot

# %%
angle = np.pi / 180 * 20
rotation_matrix = np.array([[np.cos(angle), -np.sin(angle)], [np.sin(angle), np.cos(angle)]])
Xr = X.dot(rotation_matrix)

tree_clf_r = DecisionTreeClassifier(random_state=42)
tree_clf_r.fit(Xr, y)

plt.figure(figsize=(8, 3))
plot_decision_boundary(tree_clf_r, Xr, y, axes=[0.5, 7.5, -1.0, 1], iris=False)

plt.show()

# %%
np.random.seed(6)
Xs = np.random.rand(100, 2) - 0.5
ys = (Xs[:, 0] > 0).astype(np.float32) * 2

angle = np.pi / 4
rotation_matrix = np.array([[np.cos(angle), -np.sin(angle)], [np.sin(angle), np.cos(angle)]])
Xsr = Xs.dot(rotation_matrix)

tree_clf_s = DecisionTreeClassifier(random_state=42)
tree_clf_s.fit(Xs, ys)
tree_clf_sr = DecisionTreeClassifier(random_state=42)
tree_clf_sr.fit(Xsr, ys)

fig, axes = plt.subplots(ncols=2, figsize=(10, 4), sharey=True)
plt.sca(axes[0])
plot_decision_boundary(tree_clf_s, Xs, ys, axes=[-0.7, 0.7, -0.7, 0.7], iris=False)
plt.sca(axes[1])
plot_decision_boundary(tree_clf_sr, Xsr, ys, axes=[-0.7, 0.7, -0.7, 0.7], iris=False)
plt.ylabel("")

save_fig("sensitivity_to_rotation_plot")
plt.show()
# Out:
# Saving figure sensitivity_to_rotation_plot

# %% [markdown]
# # TW3
#
# ## Part 1

# %% [markdown]
# ## Construct decision trees
#
# #### 1. Construct  a decision tree using the following parameters
#
# - Use information gain (entropy) measure
# - Apply k=10 cross validation and print a summary of statistics (performance evaluation) for each fold
#
#
# #### 2. Compare the performance results with those of the decision tree using Gini index measure in the above example
#
# #### 3. For both trees, change the following parameters and observe the changes:
#
# - The depth of tree: currently max_depth=2 in the model training step. Change the depth 3, 4, 5 and check if this affects the overall results.
#
# - The k value for cross validation is currently set to 3. Change k value, k = 5, 7, 10 and check if this affects the overall results.

# %% [markdown]
# ### Entropy measure decision tree

# %%
# entropy measure decision tree
X = iris.data[:, 2:]
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

entropy_tree_clf = DecisionTreeClassifier(max_depth=2, criterion="entropy", random_state=42)
entropy_tree_clf.fit(X_train, y_train)

y_pred = entropy_tree_clf.predict(X_test)

confusion_mat = confusion_matrix(y_test, y_pred)
print(confusion_mat)
plot_confusion_matrix(confusion_mat, 3)

export_graphviz(
        entropy_tree_clf,
        out_file=os.path.join(IMAGES_PATH, "entropy_iris_tree.dot"),
        feature_names=iris.feature_names[2:],
        class_names=iris.target_names,
        rounded=True,
        filled=True
    )

Source.from_file(os.path.join(IMAGES_PATH, "entropy_iris_tree.dot"))
# Out:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  1 12]]

# %%
# entropy measure decision tree k-cross validation
kf = KFold(n_splits=10, random_state=None, shuffle=True)

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    entropy_tree_clf.fit(X_train, y_train)
    
    y_pred = entropy_tree_clf.predict(X_test)
    
    target_names = iris.target_names
    report = classification_report(y_test, y_pred, output_dict=True, target_names=target_names)
    print(f"Average precision: {report['macro avg']['precision']}")
    print(f"Average recall: {report['macro avg']['recall']}")
    print(f"Accuracy: {report['accuracy']}")
    print()
# Out:
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# Average precision: 0.8777777777777778
# Average recall: 0.8777777777777778
# Accuracy: 0.8666666666666667
#
# Average precision: 0.9444444444444445
# Average recall: 0.9523809523809524
# Accuracy: 0.9333333333333333
#
# Average precision: 0.9523809523809524
# Average recall: 0.8888888888888888
# Accuracy: 0.9333333333333333
#
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# Average precision: 0.8666666666666667
# Average recall: 0.8888888888888888
# Accuracy: 0.8666666666666667
#
# Average precision: 0.8888888888888888
# Average recall: 0.8888888888888888
# Accuracy: 0.8666666666666667
#
# Average precision: 0.8666666666666667
# Average recall: 0.8666666666666667
# Accuracy: 0.8666666666666667
#
# Average precision: 0.8333333333333334
# Average recall: 0.9166666666666666
# Accuracy: 0.8666666666666667
#
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0

# %% [markdown]
# Using the Gini example, we get a higher floor of precision, recall, and accuracy in our results. The confusion matrix and decision tree bear out these conclusions showing very low numbers of mislabeled datapoints. Conversly, K-cross validation produces a larger range of results in accuracy, precision, and recall but also produces results with 100% accuracy, precision, and recall which aren't achieved in the Gini example.

# %% [markdown]
# ### max_depth changes

# %%
# gini tree depth changes
X = iris.data[:, 2:]
y = iris.target
target_names = iris.target_names

for depth in [2, 3, 4, 5]:
    tree_clf = DecisionTreeClassifier(max_depth=depth, criterion="gini", random_state=42)
    tree_clf.fit(X_train, y_train)
    
    y_pred = tree_clf.predict(X_test)
    report = classification_report(y_test, y_pred, output_dict=True, target_names=target_names)
    print(f"max_depth: {depth}")
    print(f"Average precision: {report['macro avg']['precision']}")
    print(f"Average recall: {report['macro avg']['recall']}")
    print(f"Accuracy: {report['accuracy']}")
    print()
# Out:
# max_depth: 2
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# max_depth: 3
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# max_depth: 4
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# max_depth: 5
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0

# %%
# entropy max_depth changes
for depth in [2, 3, 4, 5]:
    entropy_tree_clf = DecisionTreeClassifier(max_depth=depth, criterion="entropy", random_state=42)
    entropy_tree_clf.fit(X_train, y_train)
    
    y_pred = entropy_tree_clf.predict(X_test)
    report = classification_report(y_test, y_pred, output_dict=True, target_names=target_names)
    print(f"max_depth: {depth}")
    print(f"Average precision: {report['macro avg']['precision']}")
    print(f"Average recall: {report['macro avg']['recall']}")
    print(f"Accuracy: {report['accuracy']}")
    print()
# Out:
# max_depth: 2
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# max_depth: 3
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# max_depth: 4
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# max_depth: 5
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0

# %% [markdown]
# Changing the maximum tree depth doesn't increase accuracy, precision, or recall beyond a max depth of two. This indicates that adding depth to the tree is unessecary for its performance.

# %% [markdown]
# ### k value changes

# %%
# gini k-value changes () 
for k in [5, 7, 10]:
    print(f"k: {k}")
    kf = KFold(n_splits=k, random_state=None, shuffle=True)
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        tree_clf.fit(X_train, y_train)

        y_pred = tree_clf.predict(X_test)

        target_names = iris.target_names
        report = classification_report(y_test, y_pred, output_dict=True, target_names=target_names)
        print(f"Average precision: {report['macro avg']['precision']}")
        print(f"Average recall: {report['macro avg']['recall']}")
        print(f"Accuracy: {report['accuracy']}")
        print()
# Out:
# k: 5
# Average precision: 0.9305555555555555
# Average recall: 0.9305555555555555
# Accuracy: 0.9333333333333333
#
# Average precision: 0.9743589743589745
# Average recall: 0.9696969696969697
# Accuracy: 0.9666666666666667
#
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# Average precision: 0.9607843137254902
# Average recall: 0.9259259259259259
# Accuracy: 0.9333333333333333
#
# Average precision: 0.8675213675213675
# Average recall: 0.8446969696969697
# Accuracy: 0.8666666666666667
#
# k: 7
# Average precision: 0.9107142857142857
# Average recall: 0.9107142857142857
# Accuracy: 0.9090909090909091
#
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# Average precision: 0.9
# Average recall: 0.7999999999999999
# Accuracy: 0.8571428571428571
#
# Average precision: 0.9444444444444445
# Average recall: 0.9333333333333332
# Accuracy: 0.9047619047619048
#
# Average precision: 0.9583333333333334
# Average recall: 0.9444444444444445
# Accuracy: 0.9523809523809523
#
# Average precision: 0.9583333333333334
# Average recall: 0.9166666666666666
# Accuracy: 0.9523809523809523
#
# k: 10
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# Average precision: 0.9583333333333334
# Average recall: 0.8888888888888888
# Accuracy: 0.9333333333333333
#
# Average precision: 0.9523809523809524
# Average recall: 0.9166666666666666
# Accuracy: 0.9333333333333333
#
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# Average precision: 0.9333333333333332
# Average recall: 0.9333333333333332
# Accuracy: 0.9333333333333333
#
# Average precision: 0.9583333333333334
# Average recall: 0.9166666666666666
# Accuracy: 0.9333333333333333
#
# Average precision: 0.8333333333333334
# Average recall: 0.8333333333333334
# Accuracy: 0.8666666666666667
#
# Average precision: 0.8857142857142858
# Average recall: 0.8857142857142858
# Accuracy: 0.8666666666666667
#
# Average precision: 0.9047619047619048
# Average recall: 0.8888888888888888
# Accuracy: 0.8666666666666667

# %%
# entropy k value changes
for k in [5, 7, 10]:
    print(f"k: {k}")
    kf = KFold(n_splits=k, random_state=None, shuffle=True)
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        entropy_tree_clf.fit(X_train, y_train)

        y_pred = entropy_tree_clf.predict(X_test)

        target_names = iris.target_names
        report = classification_report(y_test, y_pred, output_dict=True, target_names=target_names)
        print(f"Average precision: {report['macro avg']['precision']}")
        print(f"Average recall: {report['macro avg']['recall']}")
        print(f"Accuracy: {report['accuracy']}")
        print()
# Out:
# k: 5
# Average precision: 0.9220779220779222
# Average recall: 0.9220779220779222
# Accuracy: 0.9333333333333333
#
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# Average precision: 0.9666666666666667
# Average recall: 0.9583333333333334
# Accuracy: 0.9666666666666667
#
# Average precision: 0.9523809523809524
# Average recall: 0.9393939393939394
# Accuracy: 0.9333333333333333
#
# Average precision: 0.8796296296296297
# Average recall: 0.8857142857142858
# Accuracy: 0.9
#
# k: 7
# Average precision: 0.9523809523809524
# Average recall: 0.9333333333333332
# Accuracy: 0.9545454545454546
#
# Average precision: 0.8833333333333333
# Average recall: 0.8833333333333333
# Accuracy: 0.9090909090909091
#
# Average precision: 0.9666666666666667
# Average recall: 0.9444444444444445
# Accuracy: 0.9545454545454546
#
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# Average precision: 0.9696969696969697
# Average recall: 0.9333333333333332
# Accuracy: 0.9523809523809523
#
# Average precision: 0.9111111111111111
# Average recall: 0.9111111111111111
# Accuracy: 0.9047619047619048
#
# Average precision: 0.9583333333333334
# Average recall: 0.9444444444444445
# Accuracy: 0.9523809523809523
#
# k: 10
# Average precision: 0.9583333333333334
# Average recall: 0.9166666666666666
# Accuracy: 0.9333333333333333
#
# Average precision: 0.7777777777777777
# Average recall: 0.7666666666666666
# Accuracy: 0.8
#
# Average precision: 0.9333333333333332
# Average recall: 0.9523809523809524
# Accuracy: 0.9333333333333333
#
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# Average precision: 0.9333333333333332
# Average recall: 0.9444444444444445
# Accuracy: 0.9333333333333333
#
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# Average precision: 1.0
# Average recall: 1.0
# Accuracy: 1.0
#
# Average precision: 0.625
# Average recall: 0.625
# Accuracy: 0.8666666666666667
#
# Average precision: 0.8333333333333334
# Average recall: 0.9523809523809524
# Accuracy: 0.9333333333333333
#
# Average precision: 0.9523809523809524
# Average recall: 0.9166666666666666
# Accuracy: 0.9333333333333333

# %% [markdown]
# As the number of cross-validations performed increases, the variance of the average accurarcy, precision, and recall but so does the number of perfect occurances.

# %% [markdown]
# ## Part 2
#
# #### 1. Look through an example list at:
#
# https://www.kaggle.com/dmilla/introduction-to-decision-trees-titanic-dataset
#
# #### 2. Discuss about different ways to handle the following types of data for decision tree classification.
#
# - text data (strings): in the case a dataset includes non-numerical data.
#
# - continuous data like age, weight, income, etc.
#
#
# *** Notes: This will be also a reference for our next problem-solving assignment.

# %% [markdown]
# For text data: map different text values to numerical categories if possible (Titles such as Mr., Mrs. etc, or Has_Cabin).
# Continuous data: Group continuous data into distinct bins such as less or greater than a specific value.

# %% [markdown]
# ### Submission(s): one submission per team
#
# #### - Write a short paragraph describing what you found from the process on Canvas (one submission per team).
# #### - Upload the notebook on your Git repo and write an URL link.
#
# #####       If you work in a group, one submission is good per team.
